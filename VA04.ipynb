# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcielRocha/AnalisedeDados/blob/main/VA04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Caso fictício: O Departamento Jurídico da Prefeitura de SP

# %%
pip install "transformers<5.0"
# Out:
# Requirement already satisfied: transformers<5.0 in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (3.29.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0) (1.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0) (2026.5.20)

# %%
# Importar dependências
from transformers import pipeline

# %%
# Carregar um modelo de linguagem pré-treinado
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2")

# Função para buscar respostas em um conjunto de documentos
def buscar_resposta(pergunta, documentos):
  respostas = []
  for documento in documentos:
    resposta = qa_pipeline({
        'question': pergunta,
        'context': documento
    })
    respostas.append(resposta)
  # Aqui você deve implementar a lógica para escolher a melhor resposta
  # Por exemplo, pode ser a resposta com maior score:
    melhor_resposta = max(respostas, key=lambda x: x['score']) if respostas else None
    return melhor_resposta
# Out:
# Device set to use cpu

# %%
# Exemplo de uso
pergunta = "O que garante os direitos do consumidor?"
documentos = [
    'Os direitos do consumidor exigem a disponibilização de produtos de qualidade para os consumidores',
    'As leis de trânsito estabelecem normas de circulação nas vias públicas para carros e pedestres.',
    'O regulamento de zonas verdes define as áreas protegidas e suas normas devem ser respeitadas',
    'O código tributário dispõe sobre a arrecadação de impostos e taxas sobre produtos'
]
resposta = buscar_resposta(pergunta, documentos)
print(resposta)
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/question_answering.py:395: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# {'score': 0.26865154504776, 'start': 35, 'end': 76, 'answer': 'disponibilização de produtos de qualidade'}

# %% [markdown]
# # Considerações sobre esse modelo
# É importante destacar que esse modelo não é o mais eficiente e foi apenas utilizado para fins ilustrativos, mas para melhores resultados utilizar modelos mais robustos e lógica mais elaborada para escolher melhor resposta retornada do modelo
